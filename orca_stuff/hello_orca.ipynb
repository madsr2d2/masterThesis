# %% [markdown]
# ##### Imports

# %%
import re
import copy
import shutil
from pathlib import Path

# RDKit as conformer generator
from rdkit import Chem
from rdkit.Chem import AllChem, rdMolAlign, Draw
from IPython.display import display, Markdown

# OPI imports for performing ORCA calculations and reading output
from opi.core import Calculator
from opi.input import simple_keywords
from opi.input.structures.structure import Structure
from opi.input.simple_keywords import BasisSet, Dft, ForceField, Scf, Task, Docker, SolvationModel, Solvent 
from opi.input.simple_keywords.goat import Goat
from opi.input.blocks import BlockDocker , BlockGeom, TSMode, Hybrid, geom_wrapper 
from opi.input import blocks
from opi.input.blocks.block_geom import Scan
from opi.input.blocks.base import Block, InputFilePath
# for plotting results and visualization of molecules
from opi.input.blocks import BlockGeom, Hybrid
from opi.input.blocks.base import NumList
import py3Dmol
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Utility functions

# %%
from pathlib import Path
from typing import Union, Sequence
import py3Dmol
from IPython.display import display, Markdown


def show_structure(
    structure: Union[Structure, str, Path],
    title: str = "Structure",
    stick_radius: float = 0.1,
    sphere_scale: float = 0.2,
    label_level: int = 2,
    wireframe_indices: list[int] = None,
) -> None:
    """
    Visualize a Structure or XYZ file with optional atom/bond labels and wireframe styling using py3Dmol.

    Parameters:
        structure (Structure | str | Path): Structure object or path to .xyz file.
        title (str): Title to display.
        stick_radius (float): Stick style bond radius.
        sphere_scale (float): Atom sphere scaling.
        label_level (int):
            0 = no labels,
            1 = show atom symbol + index,
            2 = as above, plus bond lengths.
        wireframe_indices (list[int]): Atom indices whose spheres will be downsized to stick radius.
    """
    if isinstance(structure, (str, Path)):
        path = Path(structure).resolve()
        if not path.exists():
            raise FileNotFoundError(f"File not found: {path}")
        structure = Structure.from_xyz(path)

    xyz_block = structure.to_xyz_block().splitlines()
    num_atoms = int(xyz_block[0])
    atom_lines = xyz_block[2:2 + num_atoms]

    atoms = []
    coords = []
    for line in atom_lines:
        parts = line.split()
        atoms.append(parts[0])
        coords.append([float(x) for x in parts[1:4]])

    mol = Chem.RWMol()
    for symbol in atoms:
        mol.AddAtom(Chem.Atom(symbol))
    conf = Chem.Conformer(len(atoms))
    for i, (x, y, z) in enumerate(coords):
        conf.SetAtomPosition(i, rdGeometry.Point3D(x, y, z))
    mol.AddConformer(conf)

    # Infer bonds
    for i in range(len(atoms)):
        for j in range(i + 1, len(atoms)):
            dist = conf.GetAtomPosition(i).Distance(conf.GetAtomPosition(j))
            ri = Chem.GetPeriodicTable().GetRcovalent(mol.GetAtomWithIdx(i).GetAtomicNum())
            rj = Chem.GetPeriodicTable().GetRcovalent(mol.GetAtomWithIdx(j).GetAtomicNum())
            if dist < 1.3 * (ri + rj):
                mol.AddBond(i, j, Chem.BondType.SINGLE)
    mol = mol.GetMol()

    viewer = py3Dmol.view(width=400, height=400)
    viewer.addModel(structure.to_xyz_block(), "xyz")
    viewer.setBackgroundColor("white")

    # Global style
    viewer.setStyle({"stick": {"radius": stick_radius}, "sphere": {"scale": sphere_scale}})

    # Override wireframe atoms
    if wireframe_indices:
        viewer.setStyle(
            {"serial": [i for i in wireframe_indices]},
            {
                "stick": {"radius": stick_radius},
                "sphere": {"scale": 0.0},  # override to match stick radius
            },
        )

    # Atom labels
    if label_level >= 1:
        for atom in mol.GetAtoms():
            idx = atom.GetIdx()
            pos = conf.GetAtomPosition(idx)
            label = f"{atom.GetSymbol()}{idx}"
            viewer.addLabel(
                label,
                {
                    "position": {"x": pos.x, "y": pos.y, "z": pos.z},
                    "fontSize": 18,
                    "fontColor": "black",
                    "backgroundColor": "white",
                    "showBackground": False,
                    "id": f"{title.lower()}_atom_{idx}",
                },
            )

    # Bond length labels
    if label_level == 2:
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            p1 = conf.GetAtomPosition(i)
            p2 = conf.GetAtomPosition(j)
            mid = {"x": (p1.x + p2.x) / 2, "y": (p1.y + p2.y) / 2, "z": (p1.z + p2.z) / 2}
            dist = p1.Distance(p2)
            viewer.addLabel(
                f"{dist:.2f}",
                {
                    "position": mid,
                    "fontSize": 18,
                    "fontColor": "black",
                    "backgroundColor": "white",
                    "showBackground": False,
                },
            )

    viewer.zoomTo()
    display(Markdown(f"### {title}"))
    viewer.show()

# %%
from typing import Union, Optional, Sequence
from pathlib import Path

from typing import Union, Optional, Sequence
from pathlib import Path

def setup_calc(
    working_dir: Optional[Union[Path, str]],
    structure: Union[Structure, str],
    basename: str = "single_molecule_calc",
    sk_list: Optional[Sequence[str]] = None,
    bk_list: Optional[Union[Block, Sequence[Block]]] = None,
    ncores: int = 12,
    memory: int = 2200,
    visualize: bool = True,
) -> Calculator:
    """
    Set up a single-molecule ORCA calculation using a Structure, path to XYZ file, or SMILES string.

    Parameters:
        working_dir (Path or str or None): Directory for input/output files.
        structure (Structure or path or SMILES): The molecule.
        basename (str): Base name for calculation.
        sk_list (list[str]): Simple keywords for ORCA input.
        bk_list (Block or list[Block] or None): Additional ORCA input blocks.
        ncores (int): Number of CPU cores.
        memory (int): Memory in MB.
        visualize (bool): Whether to visualize the structure.

    Returns:
        Calculator: Configured Calculator instance.
    """
    # Normalize and create working directory
    if isinstance(working_dir, str):
        working_dir = Path(working_dir)
    if working_dir is None:
        working_dir = Path.cwd() / basename
    working_dir = working_dir.resolve()
    working_dir.mkdir(parents=True, exist_ok=True)

    # Convert input to Structure
    if isinstance(structure, Structure):
        mol = structure
    elif isinstance(structure, str):
        path = Path(structure)
        if path.suffix == ".xyz" and path.exists():
            mol = Structure.from_xyz(path)
        else:
            # Treat as SMILES
            mol = Structure.from_smiles(structure)
    else:
        raise TypeError(f"Unsupported structure input type: {type(structure)}")

    # Save structure to XYZ
    xyz_file = working_dir / f"{basename}.xyz"
    xyz_file.write_text(mol.to_xyz_block())

    # Optional visualization
    if visualize:
        show_structure(mol, title=basename)

    # Set up Calculator
    calc = Calculator(basename=basename, working_dir=working_dir)
    calc.structure = mol
    calc.structure.charge = mol.charge
    calc.structure.multiplicity = mol.multiplicity

    if sk_list:
        calc.input.add_simple_keywords(*sk_list)

    # Add blocks
    if isinstance(bk_list, Block):
        calc.input.add_blocks(bk_list)
    elif isinstance(bk_list, Sequence):
        for bk in bk_list:
            if not isinstance(bk, Block):
                raise TypeError(f"Invalid block in bk_list: {bk}")
            calc.input.add_blocks(bk)

    # Resources
    calc.input.ncores = ncores
    calc.input.memory = memory
    calc.write_input()
    return calc

# %%
from pathlib import Path
from typing import Optional, Sequence, Union

def setup_docking_calc(
    working_dir: Union[str, Path],
    host_smiles: str,
    guest_smiles: str,
    basename: str = "docking_calc",
    sk_list: Optional[Sequence[str]] = ["xtb", "alpb(water)"],
    bk_list: Optional[Sequence[Block]] = None,
    ncores: int = 12,
    memory: int = 2200,
    visualize: bool = True,
) -> Calculator:
    """
    Set up an ORCA docking calculation using host and guest SMILES strings.

    Parameters:
        working_dir (str or Path): Base directory where 'docking' subdirectory will be created.
        host_smiles (str): SMILES string of the host molecule.
        guest_smiles (str): SMILES string of the guest molecule.
        basename (str): Base name for input/output files.
        sk_list (list[str]): Simple ORCA keywords.
        bk_list (list[Block] or None): Additional input blocks.
        ncores (int): Number of CPU cores.
        memory (int): Memory in MB.
        visualize (bool): Whether to visualize host and guest structures.

    Returns:
        Calculator: Configured Calculator instance.
    """
    # Normalize and prepare paths
    if isinstance(working_dir, str):
        working_dir = Path(working_dir)
    docking_dir = working_dir.resolve() / "docking"
    docking_dir.mkdir(parents=True, exist_ok=True)

    # Generate and save guest structure
    guest_structure = Structure.from_smiles(guest_smiles)
    guest_xyz_path = docking_dir / f"{guest_smiles.lower()}.xyz"
    guest_xyz_path.write_text(guest_structure.to_xyz_block())

    if visualize:
        show_structure(guest_structure, title="Guest")

    # Prepare Docker block
    docker_block = BlockDocker(guest=InputFilePath.from_string(guest_xyz_path.name))

    # Combine with optional blocks
    all_blocks = [docker_block]
    if bk_list:
        all_blocks.extend(bk_list)

    # Use setup_calc to build host-side calculator with guest block
    calc = setup_calc(
        working_dir=docking_dir,
        structure=host_smiles,
        basename=basename,
        sk_list=sk_list,
        bk_list=all_blocks,
        ncores=ncores,
        memory=memory,
        visualize=visualize,
    )

    return calc

# %%
from pathlib import Path
from typing import Optional, Union, Sequence
from opi.input.blocks import Block

def run_multi_step_calculation(
    working_dir: Union[str, Path],
    structure: Union[Structure, str],
    steps: Sequence[dict],
    visualize: bool = True,
    xyz_suffix: str = ".xyz",
) -> Calculator:
    """
    Run a multi-step ORCA calculation workflow, where each step builds on the geometry of the previous.

    Parameters:
        working_dir (str | Path): Root directory for the entire calculation.
        structure (Structure | str): Initial geometry, either as a Structure or path to an XYZ file.
        steps (Sequence[dict]): List of calculation step configurations.
                                 Each step is a dict that may contain:
                                    - 'basename': str
                                    - 'sk_list': list[str]
                                    - 'bk_list': list[Block] or Block
                                    - 'ncores': int
                                    - 'memory': int
        visualize (bool): If True, display the final structure using `show_structure`.
        xyz_suffix (str): Suffix used for reading the output XYZ files.

    Returns:
        Calculator: The final Calculator instance after all steps.
    """
    if isinstance(working_dir, str):
        working_dir = Path(working_dir)
    working_dir.mkdir(parents=True, exist_ok=True)

    if isinstance(structure, str):
        structure = Structure.from_xyz(structure)

    current_structure = structure

    for i, step in enumerate(steps):
        basename = step.get("basename", f"step_{i+1}")
        step_dir = working_dir / basename
        step_dir.mkdir(parents=True, exist_ok=True)

        calc = Calculator(basename=basename, working_dir=step_dir)
        calc.structure = current_structure
        calc.structure.charge = current_structure.charge
        calc.structure.multiplicity = current_structure.multiplicity

        sk_list = step.get("sk_list", [])
        bk_list = step.get("bk_list", [])
        calc.input.add_simple_keywords(*sk_list)

        if isinstance(bk_list, Block):
            calc.input.add_blocks(bk_list)
        elif isinstance(bk_list, list):
            for bk in bk_list:
                calc.input.add_blocks(bk)

        calc.input.ncores = step.get("ncores", 12)
        calc.input.memory = step.get("memory", 2200)

        calc.write_input()
        calc.run()

        # Load geometry from output
        output_file = step_dir / f"{basename}{xyz_suffix}"
        current_structure = Structure.from_xyz(output_file)

        if visualize:
            show_structure(current_structure, title=basename)

    return calc

# %% [markdown]
# ## BnOH + H2O2

# %%
# Define SMILES for host and guest
host = "c1ccccc1CO"  # Benzyl alcohol
guest = "OO"         # Hydrogen peroxide

# Define base working directory
base_dir = Path("BnOH_plus_H2O2")

# %% [markdown]
# ### Docking reactants

# %%
# Set up docking calculation
calc = setup_docking_calc(
    working_dir=base_dir,
    host_smiles=host,
    guest_smiles=guest,
    basename="BnOH_H2O2",
    visualize=True,
)
# Out:
# ### Guest
# <div id="3dmolviewer_17516508067771885"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17516508067771885" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17516508067771885 = null;
# var warn = document.getElementById("3dmolwarning_17516508067771885");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17516508067771885 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17516508067771885"),{backgroundColor:"white"});
# viewer_17516508067771885.zoomTo();
# 	viewer_17516508067771885.addModel("4\n\nO             0.6345470539155268             0.4249747620146806             0.1565541354378849\nO            -0.6363331303948183             0.4364293753229346            -0.1536139228868997\nH             1.0594836830045309            -0.4266085632425192            -0.0945598995489896\nH            -1.0576976065252390            -0.4347955740950959             0.0916196869980048\n\n","xyz");
# 	viewer_17516508067771885.setStyle({"stick": {"radius": 0.1}, "sphere": {"scale": 0.2}});
# 	viewer_17516508067771885.setBackgroundColor("white");
# 	viewer_17516508067771885.addLabel("O0",{"position": {"x": 0.6345470539155268, "y": 0.4249747620146806, "z": 0.1565541354378849}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "guest_atom_0"});
# 	viewer_17516508067771885.addLabel("O1",{"position": {"x": -0.6363331303948183, "y": 0.4364293753229346, "z": -0.1536139228868997}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "guest_atom_1"});
# 	viewer_17516508067771885.addLabel("H2",{"position": {"x": 1.0594836830045309, "y": -0.4266085632425192, "z": -0.0945598995489896}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "guest_atom_2"});
# 	viewer_17516508067771885.addLabel("H3",{"position": {"x": -1.057697606525239, "y": -0.4347955740950959, "z": 0.0916196869980048}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "guest_atom_3"});
# 	viewer_17516508067771885.addLabel("1.31",{"position": {"x": -0.0008930382396457603, "y": 0.43070206866880756, "z": 0.0014701062754925998}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false});
# 	viewer_17516508067771885.addLabel("0.98",{"position": {"x": 0.8470153684600288, "y": -0.0008169006139193136, "z": 0.03099711794444765}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false});
# 	viewer_17516508067771885.addLabel("1.00",{"position": {"x": -0.8470153684600287, "y": 0.0008169006139193413, "z": -0.030997117944447455}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false});
# 	viewer_17516508067771885.zoomTo();
# viewer_17516508067771885.render();
# });
# </script>
# ### BnOH_H2O2
# <div id="3dmolviewer_17516508067833102"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17516508067833102" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17516508067833102 = null;
# var warn = document.getElementById("3dmolwarning_17516508067833102");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17516508067833102 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17516508067833102"),{backgroundColor:"white"});
# viewer_17516508067833102.zoomTo();
# 	viewer_17516508067833102.addModel("16\n\nC            -0.1063146465849890             1.1174603973479915             0.2924620096376144\nC            -1.4367654048816716             1.0804699145653849             0.6147018856048406\nC            -2.1791249833549955            -0.0613709056985777             0.3739503659510254\nC            -1.5693768119649876            -1.1585403142150090            -0.1916321371583913\nC            -0.2261186850504231            -1.1059619609692908            -0.5112604277219198\nC             0.5410031867066472             0.0390315156662320            -0.2755829568926580\nC             1.9693653027518978             0.1313835026930921            -0.6017930269795071\nO             2.7769139331381854            -0.2855597042841862             0.4815403911784074\nH             0.4598596442192890             2.0400421036809679             0.4954850369061549\nH            -1.8732558330384343             1.9620343722130444             1.0556411921841846\nH            -3.2288520787279285            -0.1129425699926410             0.6198040963550909\nH            -2.1067462487889177            -2.0696329714710457            -0.3976196189103379\nH             0.2462600121897979            -1.9752673806819938            -0.9566637873509030\nH             2.2346470440016590             1.1872160583626921            -0.8577924701896560\nH             2.2639924745678841            -0.4922709031590178            -1.4620261401092620\nH             2.2345130948170158            -0.2960911540576360             1.3207855874953240\n\n","xyz");
# 	viewer_17516508067833102.setStyle({"stick": {"radius": 0.1}, "sphere": {"scale": 0.2}});
# 	viewer_17516508067833102.setBackgroundColor("white");
# 	viewer_17516508067833102.addLabel("C0",{"position": {"x": -0.106314646584989, "y": 1.1174603973479915, "z": 0.2924620096376144}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_0"});
# 	viewer_17516508067833102.addLabel("C1",{"position": {"x": -1.4367654048816716, "y": 1.0804699145653849, "z": 0.6147018856048406}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_1"});
# 	viewer_17516508067833102.addLabel("C2",{"position": {"x": -2.1791249833549955, "y": -0.0613709056985777, "z": 0.3739503659510254}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_2"});
# 	viewer_17516508067833102.addLabel("C3",{"position": {"x": -1.5693768119649876, "y": -1.158540314215009, "z": -0.1916321371583913}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_3"});
# 	viewer_17516508067833102.addLabel("C4",{"position": {"x": -0.2261186850504231, "y": -1.1059619609692908, "z": -0.5112604277219198}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_4"});
# 	viewer_17516508067833102.addLabel("C5",{"position": {"x": 0.5410031867066472, "y": 0.039031515666232, "z": -0.275582956892658}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_5"});
# 	viewer_17516508067833102.addLabel("C6",{"position": {"x": 1.9693653027518978, "y": 0.1313835026930921, "z": -0.6017930269795071}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_6"});
# 	viewer_17516508067833102.addLabel("O7",{"position": {"x": 2.7769139331381854, "y": -0.2855597042841862, "z": 0.4815403911784074}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_7"});
# 	viewer_17516508067833102.addLabel("H8",{"position": {"x": 0.459859644219289, "y": 2.040042103680968, "z": 0.4954850369061549}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_8"});
# 	viewer_17516508067833102.addLabel("H9",{"position": {"x": -1.8732558330384343, "y": 1.9620343722130444, "z": 1.0556411921841846}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_9"});
# 	viewer_17516508067833102.addLabel("H10",{"position": {"x": -3.2288520787279285, "y": -0.112942569992641, "z": 0.6198040963550909}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_10"});
# 	viewer_17516508067833102.addLabel("H11",{"position": {"x": -2.1067462487889177, "y": -2.0696329714710457, "z": -0.3976196189103379}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_11"});
# 	viewer_17516508067833102.addLabel("H12",{"position": {"x": 0.2462600121897979, "y": -1.9752673806819938, "z": -0.956663787350903}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_12"});
# 	viewer_17516508067833102.addLabel("H13",{"position": {"x": 2.234647044001659, "y": 1.187216058362692, "z": -0.857792470189656}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_13"});
# 	viewer_17516508067833102.addLabel("H14",{"position": {"x": 2.263992474567884, "y": -0.4922709031590178, "z": -1.462026140109262}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_14"});
# 	viewer_17516508067833102.addLabel("H15",{"position": {"x": 2.2345130948170158, "y": -0.296091154057636, "z": 1.320785587495324}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "bnoh_h2o2_atom_15"});
# 	viewer_17516508067833102.addLabel("1.37",{"position": {"x": -0.7715400257333302, "y": 1.0989651559566882, "z": 0.4535819476212275}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false});
# 	viewer_17516508067833102.addLabel("1.38",{"position": {"x": 0.21734427006082907, "y": 0.5782459565071117, "z": 0.00843952637247819}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false});
# 	viewer_17516508067833102.addLabel("1.10",{"position": {"x": 0.17677249881715, "y": 1.5787512505144798, "z": 0.3939735232718846}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false});
# 	viewer_17516508067833102.addLabel("1.38",{"position": {"x"

# %%
# Define SMILES and human-readable names
smiles_dict = {
    "c1ccccc1CO": "BnOH",   # Benzyl alcohol
    "OO": "H2O2",           # Hydrogen peroxide
}
smiles = list(smiles_dict.keys())

# Construct reaction name and base working directory
reaction_name = f"{smiles[0]}_+_{smiles[-1]}"
base_dir = Path(reaction_name)

# Clean and create base directory
# if base_dir.exists():
#     shutil.rmtree(base_dir)
# base_dir.mkdir(parents=True)

# %% [markdown]
# ### Dock reactants

# %%
show_structure("/home/madsr2d2/chem/BnOH_plus_H2O2/docking/BnOH_H2O2.docker.xyz", wireframe_indices=[0, 1, 2])
# Out:
# ### Structure
# <div id="3dmolviewer_1751657856006299"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1751657856006299" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_1751657856006299 = null;
# var warn = document.getElementById("3dmolwarning_1751657856006299");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1751657856006299 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1751657856006299"),{backgroundColor:"white"});
# viewer_1751657856006299.zoomTo();
# 	viewer_1751657856006299.addModel("20\n\nC            -0.2693139549895316            -1.1669899549913398             0.1860316158097193\nC            -1.6313431398915126            -1.1383947960359060            -0.0533061054129046\nC            -2.3008600844866458             0.0729768086789905            -0.1161614689798657\nC            -1.6032961486931714             1.2557096727317540             0.0593977588913635\nC            -0.2388147736986455             1.2282807035951295             0.2934237847910992\nC             0.4372412938685823             0.0174917773667237             0.3608605738999917\nC             1.9271614916269937            -0.0286426399479055             0.5872840136971275\nO             2.6432019004134113            -0.4407666471757457            -0.5690769308735134\nH             0.2574786843797634            -2.1081513877024829             0.2405134084322362\nH            -2.1721782037851867            -2.0631143357208930            -0.1870822819886643\nH            -3.3644931719327995             0.0946667739924003            -0.3000623122002468\nH            -2.1215141183957469             2.2017856336692803             0.0129324251829573\nH             0.3012721453116082             2.1538959932333324             0.4323578231381383\nH             2.2940515515323865             0.9504040056568156             0.9195682503615219\nH             2.1659530217525846            -0.7729754653705050             1.3511646564315491\nH             2.4525347084876703             0.1696188893601954            -1.2944082915180808\nO             3.1392829457382465            -3.2092980969293987            -0.6500449293367039\nO             2.2427623838944823            -3.5100017801048304             0.4128432422728123\nH             3.0608457125631685            -2.2302950870596989            -0.7274765293873485\nH             2.4614327913034719            -4.4355123323378560             0.6196388768011748\n\n","xyz");
# 	viewer_1751657856006299.setBackgroundColor("white");
# 	viewer_1751657856006299.setStyle({"stick": {"radius": 0.1}, "sphere": {"scale": 0.2}});
# 	viewer_1751657856006299.setStyle({"serial": [0, 1, 2]},{"stick": {"radius": 0.1}, "sphere": {"scale": 0.0}});
# 	viewer_1751657856006299.addLabel("C0",{"position": {"x": -0.2693139549895316, "y": -1.1669899549913398, "z": 0.1860316158097193}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_0"});
# 	viewer_1751657856006299.addLabel("C1",{"position": {"x": -1.6313431398915126, "y": -1.138394796035906, "z": -0.0533061054129046}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_1"});
# 	viewer_1751657856006299.addLabel("C2",{"position": {"x": -2.300860084486646, "y": 0.0729768086789905, "z": -0.1161614689798657}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_2"});
# 	viewer_1751657856006299.addLabel("C3",{"position": {"x": -1.6032961486931714, "y": 1.255709672731754, "z": 0.0593977588913635}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_3"});
# 	viewer_1751657856006299.addLabel("C4",{"position": {"x": -0.2388147736986455, "y": 1.2282807035951295, "z": 0.2934237847910992}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_4"});
# 	viewer_1751657856006299.addLabel("C5",{"position": {"x": 0.4372412938685823, "y": 0.0174917773667237, "z": 0.3608605738999917}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_5"});
# 	viewer_1751657856006299.addLabel("C6",{"position": {"x": 1.9271614916269937, "y": -0.0286426399479055, "z": 0.5872840136971275}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_6"});
# 	viewer_1751657856006299.addLabel("O7",{"position": {"x": 2.6432019004134113, "y": -0.4407666471757457, "z": -0.5690769308735134}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_7"});
# 	viewer_1751657856006299.addLabel("H8",{"position": {"x": 0.2574786843797634, "y": -2.108151387702483, "z": 0.2405134084322362}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_8"});
# 	viewer_1751657856006299.addLabel("H9",{"position": {"x": -2.1721782037851867, "y": -2.063114335720893, "z": -0.1870822819886643}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_9"});
# 	viewer_1751657856006299.addLabel("H10",{"position": {"x": -3.3644931719327995, "y": 0.0946667739924003, "z": -0.3000623122002468}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_10"});
# 	viewer_1751657856006299.addLabel("H11",{"position": {"x": -2.121514118395747, "y": 2.2017856336692803, "z": 0.0129324251829573}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_11"});
# 	viewer_1751657856006299.addLabel("H12",{"position": {"x": 0.3012721453116082, "y": 2.1538959932333324, "z": 0.4323578231381383}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_12"});
# 	viewer_1751657856006299.addLabel("H13",{"position": {"x": 2.2940515515323865, "y": 0.9504040056568156, "z": 0.9195682503615219}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_13"});
# 	viewer_1751657856006299.addLabel("H14",{"position": {"x": 2.1659530217525846, "y": -0.772975465370505, "z": 1.3511646564315491}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_14"});
# 	viewer_1751657856006299.addLabel("H15",{"position": {"x": 2.4525347084876703, "y": 0.1696188893601954, "z": -1.2944082915180808}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_15"});
# 	viewer_1751657856006299.addLabel("O16",{"position": {"x": 3.1392829457382465, "y": -3.2092980969293987, "z": -0.6500449293367039}, "fontSize": 18, "fontColor": "black", "backgroundColor": "white", "showBackground": false, "id": "structure_atom_16"});
# 	viewer_17

# %%
# Create docking subdirectory
docking_dir = base_dir / "docking"
if docking_dir.exists():
    shutil.rmtree(docking_dir)
docking_dir.mkdir(parents=True)

# Set up docking calculation
sk_list = ["xtb alpb(water)"]
calc = setup_docker_from_smiles(
    working_dir=docking_dir,
    sk_list=sk_list,
    smiles=smiles,
)
# Out:
# ### Host
# <div id="3dmolviewer_1751226598150372"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1751226598150372" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_1751226598150372 = null;
# var warn = document.getElementById("3dmolwarning_1751226598150372");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1751226598150372 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1751226598150372"),{backgroundColor:"white"});
# viewer_1751226598150372.zoomTo();
# 	viewer_1751226598150372.addModel("16\n\nC             0.1361590215736087             1.1536765406501035            -0.3516786469084188\nC             1.4980715871416639             1.2200257574735893            -0.1389213641288948\nC             2.2109133407196220             0.0948163494634948             0.2101050047680240\nC             1.5439733657977235            -1.1045044057575752             0.3449954318521106\nC             0.1648966474406894            -1.1765559231332936             0.1305545995211269\nC            -0.5544553677151057            -0.0358440948876199            -0.2227306618426157\nC            -2.0237768285167115            -0.0756257693735093            -0.4587817096250407\nO            -2.7492521011936368             0.1643449045360023             0.6976173324155853\nH            -0.3988620158495591             2.0544066640031691            -0.6251542728785543\nH             1.9940008573433539             2.1796999857697821            -0.2531307069366101\nH             3.2710745584942842             0.1030446300409717             0.3846214696652869\nH             2.0666706720558077            -2.0118523655595082             0.6177800199693075\nH            -0.3531908331607226            -2.1365823875950696             0.2411545133126138\nH            -2.2370016341382502             0.6673997231645865            -1.2456781409366011\nH            -2.3598505833384169            -1.0684413749040660            -0.8291184050957580\nH            -2.2093706866543745            -0.0280082338910130             1.4983655368484297\n\n","xyz");
# 	viewer_1751226598150372.setStyle({"stick": {"radius": 0.1}, "sphere": {"scale": 0.2}});
# 	viewer_1751226598150372.setBackgroundColor("white");
# 	viewer_1751226598150372.addLabel("C0",{"position": {"x": 0.1361590215736087, "y": 1.1536765406501035, "z": -0.3516786469084188}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_0"});
# 	viewer_1751226598150372.addLabel("C1",{"position": {"x": 1.4980715871416639, "y": 1.2200257574735893, "z": -0.1389213641288948}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_1"});
# 	viewer_1751226598150372.addLabel("C2",{"position": {"x": 2.210913340719622, "y": 0.0948163494634948, "z": 0.210105004768024}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_2"});
# 	viewer_1751226598150372.addLabel("C3",{"position": {"x": 1.5439733657977235, "y": -1.1045044057575752, "z": 0.3449954318521106}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_3"});
# 	viewer_1751226598150372.addLabel("C4",{"position": {"x": 0.1648966474406894, "y": -1.1765559231332936, "z": 0.1305545995211269}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_4"});
# 	viewer_1751226598150372.addLabel("C5",{"position": {"x": -0.5544553677151057, "y": -0.0358440948876199, "z": -0.2227306618426157}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_5"});
# 	viewer_1751226598150372.addLabel("C6",{"position": {"x": -2.0237768285167115, "y": -0.0756257693735093, "z": -0.4587817096250407}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_6"});
# 	viewer_1751226598150372.addLabel("O7",{"position": {"x": -2.749252101193637, "y": 0.1643449045360023, "z": 0.6976173324155853}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_7"});
# 	viewer_1751226598150372.addLabel("H8",{"position": {"x": -0.3988620158495591, "y": 2.054406664003169, "z": -0.6251542728785543}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_8"});
# 	viewer_1751226598150372.addLabel("H9",{"position": {"x": 1.9940008573433539, "y": 2.179699985769782, "z": -0.2531307069366101}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_9"});
# 	viewer_1751226598150372.addLabel("H10",{"position": {"x": 3.271074558494284, "y": 0.1030446300409717, "z": 0.3846214696652869}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_10"});
# 	viewer_1751226598150372.addLabel("H11",{"position": {"x": 2.0666706720558077, "y": -2.011852365559508, "z": 0.6177800199693075}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_11"});
# 	viewer_1751226598150372.addLabel("H12",{"position": {"x": -0.3531908331607226, "y": -2.1365823875950696, "z": 0.2411545133126138}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_12"});
# 	viewer_1751226598150372.addLabel("H13",{"position": {"x": -2.23700163413825, "y": 0.6673997231645865, "z": -1.2456781409366011}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_13"});
# 	viewer_1751226598150372.addLabel("H14",{"position": {"x": -2.359850583338417, "y": -1.068441374904066, "z": -0.829118405095758}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_14"});
# 	viewer_1751226598150372.addLabel("H15",{"position": {"x": -2.2093706866543745, "y": -0.028008233891013, "z": 1.4983655368484297}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "host_atom_15"});
# 	viewer_1751226598150372.zoomTo();
# viewer_1751226598150372.render();
# });
# </script>
# ### Guest
# <div id="3dmolviewer_17512265981525006"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17512265981525006" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17512265981525006 = null;
# var warn = document.getElementById("3dmolwarning_17512265981525006");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17512265981525006 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17512265981525006"),{backgroundColor:"white"});
# viewer_17512265981525006.zoomTo();
# 	viewer_17512265981525006.addModel("4\n\nO            -0.6754690420876989            -0.4559420289757052            -0.0781175637342198\nO             0.6261961777634134            -0.4568840392355286             0.0805197819746192\nH            -0.9827256758190477             0.4785575389954333             0.0499859252056928\nH             1.0319985401433329             0.4342685292158010            -0.0523881434460912\n\n","xyz");
# 	viewer_17512265981525006.setStyle({"stick": {"radius": 0.1}, "sphere": {"scale": 0.2}});
# 	viewer_17512265981525006.setBackgroundColor("white");
# 	viewer_17512265981525006.addLabel("O0",{"position": {"x": -0.6754690420876989, "y": -0.4559420289757052, "z": -0.0781175637342198}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "guest_atom_0"});
# 	viewer_17512265981525006.addLabel("O1",{"position": {"x": 0.6261961777634134, "y": -0.4568840392355286, "z": 0.0805197819746192}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "guest_atom_1"});
# 	viewer_17512265981525006.addLabel("H2",{"position": {"x": -0.9827256758190477, "y": 0.4785575389954333, "z": 0.0499859252056928}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "guest_atom_2"});
# 	viewer_17512265981525006.addLabel("H3",{"position": {"x": 1.031998540143333, "y": 0.434268529215801, "z": -0.0523881434460912}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "guest_atom_3"});
# 	viewer_17512265981525006.zoomTo();
# viewer_17512265981525006.render();
# });
# </script>

# %%
# Run calculation
calc.run()

# %%
# docked structure
output = calc.get_output()
docked_structure = Structure.from_xyz(docking_dir / f"{output.basename}.docker.xyz")
# Show final geometry
show_structure(docked_structure, title=f"{output.basename}.docker.xyz")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 # docked structure
#       2 output = calc.get_output()
# ----> 3 docked_structure = Structure.from_xyz(docking_dir / f"{output.basename}.docker.xyz")
#       4 # Show final geometry
#       5 show_structure(docked_structure, title=f"{output.basename}.docker.xyz")
#
# NameError: name 'docking_dir' is not defined

# %% [markdown]
# ### Scan reaction coordinate

# %%
# Create docking subdirectory

blocks.BlockGeom(cartfallback=True, constraints=BlockGeom.constraint_str(["strings="]))


scan_dir = Path.cwd() / "scan"
scan_dir.mkdir(parents=True)
sk_list = ["xtb alpb(water)", "opt"]

# Parse scan string to Scan object
# scan = BlockGeom.scan_str("B 13 17 = 4, 0.96, 10")
# BlockGeom.ts_active_atoms
# ts_str = BlockGeom.tsmode_str()
# constraint = BlockGeom.constraint_str("B 13 16 = 4, 0.  96, 10")

# active_atomes = Hybrid
# active_atomes.atom1 = 13
# active_atomes.atom2 = 17
# active_atomes.atom3 = 6
# # Create BlockGeom and assign scan
geom_block = BlockGeom()
# geom_block.scan = scan
# geom_block.fullscan = True
# geom_block.ts_active_atoms = Hybrid(mode="A",list=NumList([13, 17, 6, 16]))
geom_block.constraints = BlockGeom.constraint_str(["a 6 13 17 175.0 C", "B 13 17 2.0 C" , "a 13 17 16 175.0 c"])
# geom_block.coordsys = "cartesian"

# # geom_block.ts_mode = TSMode({'atom1': 13,'atom2': 17,'atom3':6})  # Active atoms for TS scan

# Assemble block list
bk_list = [geom_block]

# Run calculation setup
calc1 = setup_single_structure_calc(
    working_dir=Path.cwd() / ,
    sk_list=sk_list,
    bk_list=bk_list,
    structure=docked_structure,
    basename=reaction_name + "_scan",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 37
#      30 bk_list = [geom_block]
#      32 # Run calculation setup
#      33 calc1 = setup_single_structure_calc(
#      34     working_dir=scan_dir,
#      35     sk_list=sk_list,
#      36     bk_list=bk_list,
# ---> 37     structure=docked_structure,
#      38     basename=reaction_name + "_scan",
#      39 )
#
# NameError: name 'docked_structure' is not defined

# %%
# Run calculation
calc1.run()

# %%
# docked structure
output = calc1.get_output()
docked_structure = Structure.from_xyz(scan_dir / f"{output.basename}.xyz")
# Show final geometry
show_structure(docked_structure, title=f"{output.basename}.xyz")
# Out:
# ### c1ccccc1CO_+_OO_scan.xyz
# <div id="3dmolviewer_17515715428184197"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17515715428184197" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17515715428184197 = null;
# var warn = document.getElementById("3dmolwarning_17515715428184197");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17515715428184197 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17515715428184197"),{backgroundColor:"white"});
# viewer_17515715428184197.zoomTo();
# 	viewer_17515715428184197.addModel("20\n\nC            -0.0077846184194800             1.1011494090307401             0.4596084207364200\nC             1.3583626513946900             1.3162886550537900             0.4863519750890000\nC             2.2230336824045498             0.3437928822917300             0.0123149799360400\nC             1.7153084568616299            -0.8446313763920300            -0.4853066813372800\nC             0.3486274013857500            -1.0624229571786601            -0.5052870024438000\nC            -0.5237772126689800            -0.0901170138545800            -0.0349361717684100\nC            -2.0159391466576602            -0.3080399881355000            -0.0714816933288700\nO            -2.6949609248236399             0.2063161377950400             1.0575241606516499\nH            -0.6901370921599300             1.8549309819669200             0.8241736509968300\nH             1.7486833335029801             2.2453962716962499             0.8739351881300800\nH             3.2893793717810298             0.5113915509452700             0.0304985459892700\nH             2.3857001201337402            -1.6060149270009600            -0.8551350869311000\nH            -0.0452051713780400            -1.9911240749657000            -0.8920020150558799\nH            -2.4363144586840102             0.2309223071643100            -0.9301252321206300\nH            -2.2377921955912998            -1.3758600649849699            -0.1977939648780500\nH            -2.3775195553784800            -0.2476868111134100             1.8499323298192301\nO            -3.9052499485559902             1.7431282574580100            -3.6283055926089700\nO            -3.3521783304162498             1.1288811290102101            -2.4646816669609701\nH            -3.2153193979261498             1.5936910145858600            -4.2986021452705403\nH            -4.0313856186524202             1.3419336223936600            -1.7996620526205500\n\n","xyz");
# 	viewer_17515715428184197.setStyle({"stick": {"radius": 0.1}, "sphere": {"scale": 0.2}});
# 	viewer_17515715428184197.setBackgroundColor("white");
# 	viewer_17515715428184197.addLabel("C0",{"position": {"x": -0.00778461841948, "y": 1.10114940903074, "z": 0.45960842073642}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_0"});
# 	viewer_17515715428184197.addLabel("C1",{"position": {"x": 1.35836265139469, "y": 1.31628865505379, "z": 0.486351975089}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_1"});
# 	viewer_17515715428184197.addLabel("C2",{"position": {"x": 2.22303368240455, "y": 0.34379288229173, "z": 0.01231497993604}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_2"});
# 	viewer_17515715428184197.addLabel("C3",{"position": {"x": 1.71530845686163, "y": -0.84463137639203, "z": -0.48530668133728}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_3"});
# 	viewer_17515715428184197.addLabel("C4",{"position": {"x": 0.34862740138575, "y": -1.06242295717866, "z": -0.5052870024438}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_4"});
# 	viewer_17515715428184197.addLabel("C5",{"position": {"x": -0.52377721266898, "y": -0.09011701385458, "z": -0.03493617176841}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_5"});
# 	viewer_17515715428184197.addLabel("C6",{"position": {"x": -2.01593914665766, "y": -0.3080399881355, "z": -0.07148169332887}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_6"});
# 	viewer_17515715428184197.addLabel("O7",{"position": {"x": -2.69496092482364, "y": 0.20631613779504, "z": 1.05752416065165}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_7"});
# 	viewer_17515715428184197.addLabel("H8",{"position": {"x": -0.69013709215993, "y": 1.85493098196692, "z": 0.82417365099683}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_8"});
# 	viewer_17515715428184197.addLabel("H9",{"position": {"x": 1.74868333350298, "y": 2.24539627169625, "z": 0.87393518813008}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_9"});
# 	viewer_17515715428184197.addLabel("H10",{"position": {"x": 3.28937937178103, "y": 0.51139155094527, "z": 0.03049854598927}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_10"});
# 	viewer_17515715428184197.addLabel("H11",{"position": {"x": 2.38570012013374, "y": -1.60601492700096, "z": -0.8551350869311}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_11"});
# 	viewer_17515715428184197.addLabel("H12",{"position": {"x": -0.04520517137804, "y": -1.9911240749657, "z": -0.89200201505588}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_12"});
# 	viewer_17515715428184197.addLabel("H13",{"position": {"x": -2.43631445868401, "y": 0.23092230716431, "z": -0.93012523212063}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_13"});
# 	viewer_17515715428184197.addLabel("H14",{"position": {"x": -2.2377921955913, "y": -1.37586006498497, "z": -0.19779396487805}, "backgroundColor": "white", "fontColor": "black", "fontSize": 18, "showBackground": false, "fontOpacity": 1.0, "id": "c1ccccc1co_+_oo_scan.xyz_atom_14"});
# 	viewer_17515715428184197.addLabel("H15",{"position": {"x": -2.37751955537848, "y": -0.24768681111341, "z": 1.84993232981923}, "backgroundColor": "white", "fontC

# %% [markdown]
# ### XTB-TS

# %%
# Create docking subdirectory
scan_dir = base_dir / "ts"
scan_dir.mkdir(parents=True)
sk_list = ["xtb alpb(water) opt"]

# Parse scan string to Scan object
scan = BlockGeom.scan_str("B 13 16 = 4, 0.96, 10")
# constraint = BlockGeom.constraint_str("B 13 16 = 4, 0.96, 10")

# Create BlockGeom and assign scan
geom_block = BlockGeom()
geom_block.scan = scan

# Assemble block list
bk_list = [geom_block]

# Run calculation setup
calc1 = setup_single_structure_calc(
    working_dir=scan_dir,
    sk_list=sk_list,
    bk_list=bk_list,
    structure=docked_structure,
    basename=reaction_name + "_scan",
)
